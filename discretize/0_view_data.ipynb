# %%
import os, fiona
import numpy as np
import rasterio as rio
from rasterio.warp import calculate_default_transform, reproject, Resampling
import geopandas as gpd
import fiona.crs 
import rasterio.mask
import rasterio.plot 
import pandas as pd
import matplotlib.pyplot as plt 

def plot_vector(invector, column, ofile):
    
    in_gpd = gpd.read_file(invector)
    fig, ax = plt.subplots(figsize=(9, 9))
    in_gpd.plot(column=column, ax=ax)
    ax.set_axis_off()
    fig.savefig(ofile)
    
    plt.show()   
    return

root_dir = '/glade/u/home/hongli/scratch/2020_06_02HRUcomplexity/discretize'
dem_png = os.path.join(root_dir,'plot/merit_dem.png')

# # look at west us huc12 shapefile
# print('westUS shapefile')
# westus_huc12 = '/glade/work/andywood/wreg/gis/shapes/west_huc12/WEST.huc12.shp'
# westus_huc12_plot = os.path.join(root_dir,'plot/westUS_huc12.png')
# in_gpd = gpd.read_file(westus_huc12)
# plot_vector(westus_huc12,'HUC12int',westus_huc12_plot)

# look at bighorn huc12 shapefile
print('bighorn shapefile')
bighorn_huc12 = '/glade/u/home/hongli/scratch/2020_06_02HRUcomplexity/discretize/source_data/bighorn_huc12.shp'
bighorn_huc12_plot = os.path.join(root_dir,'plot/bighorn_huc12.png')
in_gpd = gpd.read_file(bighorn_huc12)
plot_vector(bighorn_huc12,'HUC12int',bighorn_huc12_plot)

# # look at DEM raster file
# dem_merit = '/glade/u/home/andywood/rhap/common_data/geophysical/MERIT_Hydro_DEM_NLDAS/MERIT_Hydro_dem_NLDAS.tif'
# with rio.open(dem_merit) as src:
#     raster_value  = src.read(1)
# #     raster_mask = src.read_masks(1)

#     fig, (axrgb, axhist) = plt.subplots(1, 2, figsize=(14,7))
#     rio.plot.show(raster_value, ax=axrgb)
#     rio.plot.show_hist(raster_value, bins=50, histtype='stepfilled',
#                        lw=0.0, stacked=False, alpha=0.3, ax=axhist)
#     fig.savefig(dem_png)
#     plt.show()
# Out:
# bighorn shapefile

# %%
# look at radiaiton raster
import os, fiona
import numpy as np
import rasterio as rio
from rasterio.warp import calculate_default_transform, reproject, Resampling
import geopandas as gpd
import fiona.crs 
import rasterio.mask
import rasterio.plot 
import pandas as pd
import matplotlib.pyplot as plt 

def plot_vector(invector, column, ofile):
    
    in_gpd = gpd.read_file(invector)
    fig, ax = plt.subplots(figsize=(9, 9))
    in_gpd.plot(column=column, ax=ax)
    ax.set_axis_off()
    fig.savefig(ofile)
    
    plt.show()   
    return

root_dir = '/glade/u/home/hongli/scratch/2020_06_02HRUcomplexity/discretize/shoshone'
ofile = os.path.join(root_dir,'plot/radiation.png')

# look at raster file
rad_raster = '/glade/u/home/hongli/scratch/2020_06_02HRUcomplexity/discretize/shoshone/step9_merge_raw_Sw/sw.tif'
with rio.open(rad_raster) as src:
    raster_value  = src.read(1)
    raster_value = np.where(raster_value==-9999,np.nan,raster_value)
#     raster_mask = src.read_masks(1)

    fig, (axrgb, axhist) = plt.subplots(1, 2, figsize=(14,7))
    rio.plot.show(raster_value, ax=axrgb)
    rio.plot.show_hist(raster_value, bins=50, histtype='stepfilled',
                       lw=0.0, stacked=False, alpha=0.3, ax=axhist)
    fig.savefig(ofile)
    plt.show()
# Out:
# /glade/u/home/hongli/tools/miniconda3/envs/conda_hongli/lib/python3.8/site-packages/numpy/lib/histograms.py:839: RuntimeWarning: invalid value encountered in greater_equal
#   keep = (tmp_a >= first_edge)
# /glade/u/home/hongli/tools/miniconda3/envs/conda_hongli/lib/python3.8/site-packages/numpy/lib/histograms.py:840: RuntimeWarning: invalid value encountered in less_equal
#   keep &= (tmp_a <= last_edge)

# %%
raster_value = raster_value[raster_value!=-9999]
np.unique(raster_value)
# Out:
# array([ 31.12645688,  31.13220511,  31.13385793, ..., 366.97365191,
#        367.09238478, 367.26368141])
